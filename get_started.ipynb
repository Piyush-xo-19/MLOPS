# %% [markdown]
# ML FLOW TRACKING SERVER

# %%
#mlflow tracking server 
import mlflow
mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment("checking local host connection ")
# Out:
# 2026/01/07 02:05:34 INFO mlflow.tracking.fluent: Experiment with name 'checking local host connection ' does not exist. Creating a new experiment.
# <Experiment: artifact_location='mlflow-artifacts:/1', creation_time=1767731734719, experiment_id='1', last_update_time=1767731734719, lifecycle_stage='active', name='checking local host connection ', tags={}>

# %%
with mlflow.start_run():
    mlflow.log_metric("test",1)
    mlflow.log_metric("piyush",2)
# Out:
# 🏃 View run kindly-fawn-212 at: http://127.0.0.1:5000/#/experiments/1/runs/54a3fbbca14145718dd956f3b904c32e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
